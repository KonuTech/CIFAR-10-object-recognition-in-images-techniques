# %% [markdown]
# # cifar100 dataset - image classification of 100 categories

# %% [markdown]
# https://www.cs.toronto.edu/~kriz/cifar.html

# %%
import os
os.chdir('C:\\Users\\KonuTech\\Downloads\\CIFAR-100-object-recognition-in-images-techniques')

# %%
from functions import *
from labels import *
from tensorflow.keras.datasets import cifar100

# %%
# The data, shuffled and split between train and test sets:
(X_train, y_train), (X_test, y_test) = cifar100.load_data()

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# # 1. Labels

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
len(y_train)
# Out:
# 50000

# %%
labels_to_show = []
for i in range(len(y_train)):
    if (i + 1) % 10000 == 0:
        print(y_train[i])
# Out:
# [23]
# [30]
# [22]
# [75]
# [73]

# %%
y_train[0:5]
# Out:
# array([[19],
#        [29],
#        [ 0],
#        [11],
#        [ 1]])

# %%
s1 = pd.DataFrame(y_train[0:5], columns=["idx"])
s1
# Out:
#    idx
# 0   19
# 1   29
# 2    0
# 3   11
# 4    1

# %%
s1 = s1.set_index("idx")
s1
# Out:
# Empty DataFrame
# Columns: []
# Index: [19, 29, 0, 11, 1]

# %%
s2_dict = {19: 'cattle', 29: 'dinosaur', 0: 'apple', 11: 'boy', 1: 'aquarium_fish'}
s2_dict
# Out:
# {19: 'cattle', 29: 'dinosaur', 0: 'apple', 11: 'boy', 1: 'aquarium_fish'}

# %%
s2 = pd.DataFrame.from_dict(s2_dict, orient='index', columns=["label"])
s2
# Out:
#             label
# 19         cattle
# 29       dinosaur
# 0           apple
# 11            boy
# 1   aquarium_fish

# %%
pd.concat([s1, s2], axis=1)
# Out:
#             label
# 19         cattle
# 29       dinosaur
# 0           apple
# 11            boy
# 1   aquarium_fish

# %% [markdown]
# # 2. Training set

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# ### First image

# %%
X_train[0].shape
# Out:
# (32, 32, 3)

# %%
plt.imshow(X_train[0])

# %% [markdown]
# ### Last image

# %%
X_train[-1].shape
# Out:
# (32, 32, 3)

# %%
plt.imshow(X_train[-1])

# %% [markdown]
# ### Every 10 000th image

# %%
images_to_show = []
for i, image in enumerate(X_train):
    if (i + 1) % 10000 == 0:
        images_to_show.append(i)

# %%
plt.figure(figsize=(30,15))
columns = 5
for i, image in enumerate(X_train[images_to_show]):
    plt.subplot(len(images_to_show) / columns + 1, columns, i + 1)
    plt.imshow(image)

# %% [markdown]
# # 3. Test set

# %%
X_test.shape
# Out:
# (10000, 32, 32, 3)

# %% [markdown]
# ### First image

# %%
X_test[0].shape
# Out:
# (32, 32, 3)

# %%
plt.imshow(X_test[0])

# %% [markdown]
# ### Last image

# %%
X_test[-1].shape
# Out:
# (32, 32, 3)

# %%
plt.imshow(X_test[-1])

# %% [markdown]
# ### Every 1000th image

# %%
images_to_show = []
for i, image in enumerate(X_test):
    if (i + 1) % 1000 == 0:
        images_to_show.append(i)

# %%
plt.figure(figsize=(30,15))
columns = 5
for i, image in enumerate(X_test[images_to_show]):
    plt.subplot(len(images_to_show) / columns + 1, columns, i + 1)
    plt.imshow(image)
